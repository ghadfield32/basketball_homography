# %%
# import the inference-sdk
from inference_sdk import InferenceHTTPClient

# initialize the client
CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="htpcxp3XQh7SsgMfjJns"
)

# infer on a local image
result = CLIENT.infer("../data/images/luka.jpg", model_id="basketball-and-hoop-7xk0h/1")
print(result)
# Out:
# {'inference_id': '4645db64-0bf4-4781-80fd-dc5a2c18c561', 'time': 0.04145899299987832, 'image': {'width': 308, 'height': 164}, 'predictions': []}
